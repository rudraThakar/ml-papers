# %%
import pandas as pd
import requests

# %%
url = "https://api.themoviedb.org/3/genre/movie/list?language=en"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxNzZkZGVkMGRjZTliYWM0MTBkNGJjNWY4YmRkOWZiNCIsIm5iZiI6MTc0OTg5ODM2OS44NzY5OTk5LCJzdWIiOiI2ODRkNTQ4MWFkZGJlYThhMTg1Yzc4YTAiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.cRpLrUTGcj5kl-ycmprtfV5FDnG9w931VFFJjYnjtcc"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":16,"name":"Animation"},{"id":35,"name":"Comedy"},{"id":80,"name":"Crime"},{"id":99,"name":"Documentary"},{"id":18,"name":"Drama"},{"id":10751,"name":"Family"},{"id":14,"name":"Fantasy"},{"id":36,"name":"History"},{"id":27,"name":"Horror"},{"id":10402,"name":"Music"},{"id":9648,"name":"Mystery"},{"id":10749,"name":"Romance"},{"id":878,"name":"Science Fiction"},{"id":10770,"name":"TV Movie"},{"id":53,"name":"Thriller"},{"id":10752,"name":"War"},{"id":37,"name":"Western"}]}

# %%
url = "https://api.themoviedb.org/3/account/22076799/rated/movies?language=en-US&page=1&sort_by=created_at.asc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxNzZkZGVkMGRjZTliYWM0MTBkNGJjNWY4YmRkOWZiNCIsIm5iZiI6MTc0OTg5ODM2OS44NzY5OTk5LCJzdWIiOiI2ODRkNTQ4MWFkZGJlYThhMTg1Yzc4YTAiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.cRpLrUTGcj5kl-ycmprtfV5FDnG9w931VFFJjYnjtcc"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[],"total_pages":0,"total_results":0}

# %%
url = "https://api.themoviedb.org/3/certification/movie/list"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxNzZkZGVkMGRjZTliYWM0MTBkNGJjNWY4YmRkOWZiNCIsIm5iZiI6MTc0OTg5ODM2OS44NzY5OTk5LCJzdWIiOiI2ODRkNTQ4MWFkZGJlYThhMTg1Yzc4YTAiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.cRpLrUTGcj5kl-ycmprtfV5FDnG9w931VFFJjYnjtcc"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"certifications":{"DE":[{"certification":"12","meaning":"Children 12 or older admitted, children between 6 and 11 only when accompanied by parent or a legal guardian.","order":3},{"certification":"18","meaning":"No youth admitted, only adults.","order":5},{"certification":"0","meaning":"No age restriction.","order":1},{"certification":"6","meaning":"No children younger than 6 years admitted.","order":2},{"certification":"16","meaning":"Children 16 or older admitted, nobody under this age admitted.","order":4}],"BR":[{"certification":"14","meaning":"Not recommended for minors under fourteen. More violent material, stronger sex references and/or nudity.","order":4},{"certification":"16","meaning":"Not recommended for minors under sixteen. Scenes featuring production, trafficking and/or use of illegal drugs, hyper-realistic sex, sexual violence, abortion, torture, mutilation, suicide, trivialization of violence and death penalty.","order":5},{"certification":"L","meaning":"General Audi
# ...

# %%
url = "https://api.themoviedb.org/3/movie/changes?page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxNzZkZGVkMGRjZTliYWM0MTBkNGJjNWY4YmRkOWZiNCIsIm5iZiI6MTc0OTg5ODM2OS44NzY5OTk5LCJzdWIiOiI2ODRkNTQ4MWFkZGJlYThhMTg1Yzc4YTAiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.cRpLrUTGcj5kl-ycmprtfV5FDnG9w931VFFJjYnjtcc"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"results":[{"id":1497236,"adult":false},{"id":1497197,"adult":true},{"id":1372382,"adult":false},{"id":1497240,"adult":false},{"id":1497235,"adult":false},{"id":350018,"adult":false},{"id":1497239,"adult":false},{"id":315357,"adult":false},{"id":1496904,"adult":false},{"id":1477279,"adult":false},{"id":1221946,"adult":false},{"id":1201299,"adult":false},{"id":1313144,"adult":false},{"id":1437369,"adult":false},{"id":1477176,"adult":false},{"id":1492523,"adult":false},{"id":1492741,"adult":false},{"id":1494038,"adult":false},{"id":1314440,"adult":false},{"id":1358381,"adult":false},{"id":1484255,"adult":false},{"id":1486097,"adult":false},{"id":1492032,"adult":false},{"id":1496798,"adult":false},{"id":1496515,"adult":false},{"id":1496572,"adult":false},{"id":1496843,"adult":false},{"id":1496664,"adult":false},{"id":1496734,"adult":false},{"id":1496759,"adult":false},{"id":1496717,"adult":false},{"id":1497105,"adult":false},{"id":1492466,"adult":false},{"id":1497039,"adult":false},{"i
# ...

# %%
url = "https://api.themoviedb.org/3/collection/collection_id?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxNzZkZGVkMGRjZTliYWM0MTBkNGJjNWY4YmRkOWZiNCIsIm5iZiI6MTc0OTg5ODM2OS44NzY5OTk5LCJzdWIiOiI2ODRkNTQ4MWFkZGJlYThhMTg1Yzc4YTAiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.cRpLrUTGcj5kl-ycmprtfV5FDnG9w931VFFJjYnjtcc"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"success":false,"status_code":6,"status_message":"Invalid id: The pre-requisite id is invalid or not found."}

# %%
url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIxNzZkZGVkMGRjZTliYWM0MTBkNGJjNWY4YmRkOWZiNCIsIm5iZiI6MTc0OTg5ODM2OS44NzY5OTk5LCJzdWIiOiI2ODRkNTQ4MWFkZGJlYThhMTg1Yzc4YTAiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.cRpLrUTGcj5kl-ycmprtfV5FDnG9w931VFFJjYnjtcc"
}

response = requests.get(url, headers=headers)

# %%
print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/a3F9cXjRH488qcOqFmFZwqawBMU.jpg","genre_ids":[16,28,878],"id":1376434,"original_language":"en","original_title":"Predator: Killer of Killers","overview":"While three of the fiercest warriors in human history—a Viking raider, a ninja in feudal Japan, and a WWII pilot—are killers in their own right, they are merely prey for their new opponent: the ultimate killer of killers.","popularity":684.3914,"poster_path":"/lbimIPTVsSlnmqSW5ngEsUxtHLM.jpg","release_date":"2025-06-05","title":"Predator: Killer of Killers","video":false,"vote_average":8.0,"vote_count":422},{"adult":false,"backdrop_path":"/yBDvgpyynDsbMyK21FoQu1c2wYR.jpg","genre_ids":[9648,80,53],"id":870028,"original_language":"en","original_title":"The Accountant²","overview":"When an old acquaintance is murdered, Wolff is compelled to solve the case. Realizing more extreme measures are necessary, Wolff recruits his estranged and highly lethal brother, Brax, to help. In partner
# ...

# %%
df = pd.DataFrame(response.json()['results'])[['original_title', 'overview', 'genre_ids']]

# %%
df.head()
# Out:
#                 original_title  \
# 0  Predator: Killer of Killers
# 1              The Accountant²
# 2                        STRAW
# 3                  The Amateur
# 4                Lilo & Stitch
#
#                                             overview             genre_ids
# 0  While three of the fiercest warriors in human ...         [16, 28, 878]
# 1  When an old acquaintance is murdered, Wolff is...        [9648, 80, 53]
# 2  What will be her last straw? A devastatingly b...          [53, 18, 80]
# 3  After his life is turned upside down when his ...              [53, 28]
# 4  The wildly funny and touching story of a lonel...  [10751, 878, 35, 12]

# %%
print(df.shape)
# Out:
# (20, 3)
